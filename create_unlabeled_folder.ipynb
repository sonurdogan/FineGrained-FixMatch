# %%
import os
import shutil

BASE_DIRS = ['ignore/fly_subgroup_data/fly_subgroup_data/train/Feeding', 
            'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming',
            'ignore/fly_subgroup_data/fly_subgroup_data/train/ProbPumping']
UNLABELED_IMAGE_DIR = 'ignore/fly_all_data/unlabeled/images'
UNLABELED_LABEL_DIR = 'ignore/fly_all_data/unlabeled/labels'
LABELED_IMAGE_DIR = 'ignore/fly_all_data/labeled/images'
LABELED_LABEL_DIR = 'ignore/fly_all_data/labeled/labels'

fine_grained_labels = { 'ignore/fly_subgroup_data/fly_subgroup_data/train/Feeding/class1': 8,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Feeding/class2': 9,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming/class1': 3,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming/class2': 4,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming/class3': 5,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming/class4': 6,
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/Grooming/class5': 7,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/ProbPumping/class1': 0,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/ProbPumping/class2': 1,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/train/ProbPumping/class3': 2}
# # Ensure labeled dirs exist
os.makedirs(LABELED_IMAGE_DIR, exist_ok=True)
os.makedirs(LABELED_LABEL_DIR, exist_ok=True)

# Walk through Feeding and Grooming
for base in BASE_DIRS:
    if not os.path.isdir(base):
        continue
    for class_folder in os.listdir(base):
        class_path = os.path.join(base, class_folder)
        if not os.path.isdir(class_path):
            continue
        for split in ['train', 'val']:
            split_path = os.path.join(class_path, split)
            if not os.path.isdir(split_path):
                continue
            for image_name in os.listdir(split_path):
                if not image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                    continue  # skip non-images


                new_label = fine_grained_labels.get(class_path , None)

                # Source paths
                src_image_path = os.path.join(UNLABELED_IMAGE_DIR, image_name)
                label_name = os.path.splitext(image_name)[0] + '.txt'
                src_label_path = os.path.join(UNLABELED_LABEL_DIR, label_name)
                
                # # Target paths
                dst_image_path = os.path.join(LABELED_IMAGE_DIR, image_name)
                dst_label_path = os.path.join(LABELED_LABEL_DIR, label_name)

                # Move image
                if os.path.exists(src_image_path):
                    shutil.move(src_image_path, dst_image_path)
                    print(f"Moved image: {image_name}")
                else:
                    print(f"Image not found in unlabeled: {image_name}")

                # Move label
                if os.path.exists(src_label_path):
                    shutil.move(src_label_path, dst_label_path)
                    print(f"Moved label: {label_name}")
                    
                    # Read the existing line
                    with open(dst_label_path, 'r') as f:
                        original_line = f.readline().strip()

                    # Prepend the fine-grained label
                    new_line = f"{new_label} {original_line}"

                    # Write it back
                    with open(dst_label_path, 'w') as f:
                        f.write(new_line + '\n')

                else:
                    print(f"Label not found in unlabeled: {label_name}")
# Out:
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_20983.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_20983.txt
# Moved image: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_2351.jpg
# Moved label: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_2351.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_20396.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_20396.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_2553.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_2553.txt
# Moved image: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_10751.jpg
# Moved label: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_10751.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_4398.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_4398.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_5124.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_5124.txt
# Moved image: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_474.jpg
# Moved label: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_474.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_2891.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_2891.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_3948.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_3948.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_2429.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_2429.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_22101.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_22101.txt
# Moved image: R30G03-R58H05_1-09102024154558_ds_1Hz_543.jpg
# Moved label: R30G03-R58H05_1-09102024154558_ds_1Hz_543.txt
# Moved image: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_4606.jpg
# Moved label: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_4606.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_4154.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_4154.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_11951.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_11951.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_6340.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_6340.txt
# Moved image: R30G03-R58H05_1-09102024154558_ds_1Hz_7437.jpg
# Moved label: R30G03-R58H05_1-09102024154558_ds_1Hz_7437.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_28788.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_28788.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_737.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_737.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_1900.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_1900.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_3140.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_3140.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_5015.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_5015.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_6691.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_6691.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_28580.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_28580.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_5774.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_5774.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_8319.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_8319.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_3541.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_3541.txt
# Moved image: R30G03-R58H05_1-09102024154558_ds_1Hz_35667.jpg
# Moved label: R30G03-R58H05_1-09102024154558_ds_1Hz_35667.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_26724.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_26724.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_24488.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_24488.txt
# Moved image: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_14326.jpg
# Moved label: Empty_Split_Fly082124_2-08212024153953_ds_1Hz_14326.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_14521.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_14521.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_19241.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_19241.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_22714.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_22714.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_19105.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_19105.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_17317.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_17317.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_1743.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_1743.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_25785.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_25785.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_8894.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_8894.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_8625.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_8625.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_6204.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_6204.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_11945.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_11945.txt
# Moved image: SS53771_9_10_15-09142024163508_ds_1Hz_25075.jpg
# Moved label: SS53771_9_10_15-09142024163508_ds_1Hz_25075.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_17903.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_17903.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_18724.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_18724.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_18219.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_18219.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_10090.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_10090.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_9640.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_9640.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_9825.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_9825.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_10326.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_10326.txt
# Moved image: 53771_6-09112024142637_ds_1Hz_10986.jpg
# Moved label: 53771_6-09112024142637_ds_1Hz_10986.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_13407.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_13407.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_20687.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_20687.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_10359.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_10359.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_9361.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_9361.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_9354.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_9354.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_4374.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_4374.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_15450.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_15450.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_12013.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_12013.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_11889.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_11889.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_14305.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_14305.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_9537.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_9537.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_13635.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_13635.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_21231.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_21231.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_16549.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_16549.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_10747.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_10747.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_10633.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_10633.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_12460.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_12460.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_10221.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_10221.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_23721.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_23721.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_12032.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_12032.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_16929.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_16929.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_9800.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_9800.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_1320.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_1320.txt
# Moved image: 53771_6-09112024142637_ds_1Hz_4147.jpg
# Moved label: 53771_6-09112024142637_ds_1Hz_4147.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_11009.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_11009.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_14529.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_14529.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_17297.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_17297.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_14704.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_14704.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_17408.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_17408.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_5020.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_5020.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_10119.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_10119.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_18723.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_18723.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_6539.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_6539.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_13011.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_13011.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_25440.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_25440.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_8821.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_8821.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_20505.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_20505.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_7078.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_7078.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_3777.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_3777.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_1299.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_1299.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_137.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_137.txt
# Moved image: empty_split_8-09162024154241_ds_10Hz_4919.jpg
# Moved label: empty_split_8-09162024154241_ds_10Hz_4919.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_393.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_393.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_34494.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_34494.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_23493.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_23493.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_8476.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_8476.txt
# Moved image: 53771_4-09112024132149_ds_1Hz_19283.jpg
# Moved label: 53771_4-09112024132149_ds_1Hz_19283.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_7577.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_7577.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_29517.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_29517.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_1031.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_1031.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_5309.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_5309.txt
# Moved image: 53771_2-09112024121932_ds_1Hz_2516.jpg
# Moved label: 53771_2-09112024121932_ds_1Hz_2516.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_10365.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_10365.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_9925.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_9925.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_4609.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_4609.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_9301.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_9301.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_4684.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_4684.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_719.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_719.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_4688.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_4688.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_14000.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_14000.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_5232.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_5232.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_24300.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_24300.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_9805.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_9805.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_34288.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_34288.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_4557.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_4557.txt
# Moved image: 53771_6-09112024142637_ds_1Hz_8267.jpg
# Moved label: 53771_6-09112024142637_ds_1Hz_8267.txt
# Moved image: empty_split_8-09162024154241_ds_10Hz_17811.jpg
# Moved label: empty_split_8-09162024154241_ds_10Hz_17811.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_7667.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_7667.txt
# Moved image: 53771_10-09122024145749_ds_1Hz_10939.jpg
# Moved label: 53771_10-09122024145749_ds_1Hz_10939.txt
# Moved image: 53771_10-09122024145749_ds_1Hz_11171.jpg
# Moved label: 53771_10-09122024145749_ds_1Hz_11171.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_16343.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_16343.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_19625.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_19625.txt
# Moved image: SS53771_9_10_14-09142024131315_ds_1Hz_13599.jpg
# Moved label: SS53771_9_10_14-09142024131315_ds_1Hz_13599.txt
# Moved image: 53771_10-09122024145749_ds_1Hz_15632.jpg
# Moved label: 53771_10-09122024145749_ds_1Hz_15632.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_17662.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_17662.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_19201.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_19201.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_26804.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_26804.txt
# Moved image: R30_4-09102024130227_ds_1Hz_10585.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_10585.txt
# Moved image: SS53771_9_10_15-09142024163508_ds_1Hz_11888.jpg
# Moved label: SS53771_9_10_15-09142024163508_ds_1Hz_11888.txt
# Moved image: Empty_Split_Fly082124_1-08212024144916_ds_1Hz_5439.jpg
# Moved label: Empty_Split_Fly082124_1-08212024144916_ds_1Hz_5439.txt
# Moved image: SS54320_9_12_6-09182024144511_ds_10Hz_22839.jpg
# Moved label: SS54320_9_12_6-09182024144511_ds_10Hz_22839.txt
# Moved image: SS53771_9_10_14-09142024131315_ds_1Hz_26861.jpg
# Moved label: SS53771_9_10_14-09142024131315_ds_1Hz_26861.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_25276.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_25276.txt
# Moved image: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_24752.jpg
# Moved label: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_24752.txt
# Moved image: 53771_7-09112024152638_ds_1Hz_33267.jpg
# Moved label: 53771_7-09112024152638_ds_1Hz_33267.txt
# Moved image: Empty_split_Fly082624_12-08262024170552_ds_1Hz_23770.jpg
# Moved label: Empty_split_Fly082624_12-08262024170552_ds_1Hz_23770.txt
# Moved image: SS54320_2-09042024132500_ds_10Hz_11489.jpg
# Moved label: SS54320_2-09042024132500_ds_10Hz_11489.txt
# Moved image: SS54320_2-09042024132500_ds_10Hz_11423.jpg
# Moved label: SS54320_2-09042024132500_ds_10Hz_11423.txt
# Moved image: 53771_8-09112024154956_ds_1Hz_25835.jpg
# Moved label: 53771_8-09112024154956_ds_1Hz_25835.txt
# Moved image: 53771_12-09122024154820_ds_1Hz_25585.jpg
# Moved label: 53771_12-09122024154820_ds_1Hz_25585.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_18596.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_18596.txt
# Moved image: SS55832_9_15_5-09192024151152_ds_10Hz_29169.jpg
# Moved label: SS55832_9_15_5-09192024151152_ds_10Hz_29169.txt
# Moved image: Empty_split_Fly082324_9-08232024153733_ds_1Hz_22743.jpg
# Moved label: Empty_split_Fly082324_9-08232024153733_ds_1Hz_22743.txt
# Moved image: SS54320_2-09042024132500_ds_10Hz_33652.jpg
# Moved label: SS54320_2-09042024132500_ds_10Hz_33652.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_18514.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_18514.txt
# Moved image: SS54320_Fly083124_4-08312024151809_ds_1Hz_23725.jpg
# Moved label: SS54320_Fly083124_4-08312024151809_ds_1Hz_23725.txt
# Moved image: 53771_8-09112024154956_ds_1Hz_25899.jpg
# Moved label: 53771_8-09112024154956_ds_1Hz_25899.txt
# Moved image: R23E10_9_18_7-09212024140858_ds_10Hz_22530.jpg
# Moved label: R23E10_9_18_7-09212024140858_ds_10Hz_22530.txt
# Moved image: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_25189.jpg
# Moved label: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_25189.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_25334.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_25334.txt
# Moved image: SS54320_Fly090124_11-09012024170312_ds_1Hz_20874.jpg
# Moved label: SS54320_Fly090124_11-09012024170312_ds_1Hz_20874.txt
# Moved image: Empty_Split_Fly082124_1-08212024144916_ds_1Hz_5610.jpg
# Moved label: Empty_Split_Fly082124_1-08212024144916_ds_1Hz_5610.txt
# Moved image: SS55832_3-09242024165057_ds_1Hz_25378.jpg
# Moved label: SS55832_3-09242024165057_ds_1Hz_25378.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_25395.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_25395.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_22268.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_22268.txt
# Moved image: SS54320_2-09042024132500_ds_10Hz_33721.jpg
# Moved label: SS54320_2-09042024132500_ds_10Hz_33721.txt

# %%
import os
import shutil

BASE_DIRS = ['ignore/fly_subgroup_data/fly_subgroup_data/test/Feeding', 
            'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming',
            'ignore/fly_subgroup_data/fly_subgroup_data/test/ProbPumping']
UNLABELED_IMAGE_DIR = 'ignore/fly_all_data/test/images'
UNLABELED_LABEL_DIR = 'ignore/fly_all_data/test/labels'
LABELED_IMAGE_DIR = 'ignore/fly_all_data/labeled_test/images'
LABELED_LABEL_DIR = 'ignore/fly_all_data/labeled_test/labels'

fine_grained_labels = { 'ignore/fly_subgroup_data/fly_subgroup_data/test/Feeding/class1': 8,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Feeding/class2': 9,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming/class1': 3,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming/class2': 4,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming/class3': 5,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming/class4': 6,
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/Grooming/class5': 7,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/ProbPumping/class1': 0,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/ProbPumping/class2': 1,  
                        'ignore/fly_subgroup_data/fly_subgroup_data/test/ProbPumping/class3': 2}
# # Ensure labeled dirs exist
os.makedirs(LABELED_IMAGE_DIR, exist_ok=True)
os.makedirs(LABELED_LABEL_DIR, exist_ok=True)

# Walk through Feeding and Grooming
for base in BASE_DIRS:
    if not os.path.isdir(base):
        continue
    for class_folder in os.listdir(base):
        class_path = os.path.join(base, class_folder)
        if not os.path.isdir(class_path):
            continue
        for split in ['test']:
            split_path = os.path.join(class_path, split)
            if not os.path.isdir(split_path):
                continue
            for image_name in os.listdir(split_path):
                if not image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                    continue  # skip non-images


                new_label = fine_grained_labels.get(class_path , None)

                # Source paths
                src_image_path = os.path.join(UNLABELED_IMAGE_DIR, image_name)
                label_name = os.path.splitext(image_name)[0] + '.txt'
                src_label_path = os.path.join(UNLABELED_LABEL_DIR, label_name)
                
                # # Target paths
                dst_image_path = os.path.join(LABELED_IMAGE_DIR, image_name)
                dst_label_path = os.path.join(LABELED_LABEL_DIR, label_name)

                # Move image
                if os.path.exists(src_image_path):
                    shutil.move(src_image_path, dst_image_path)
                    print(f"Moved image: {image_name}")
                else:
                    print(f"Image not found in unlabeled: {image_name}")

                # Move label
                if os.path.exists(src_label_path):
                    shutil.move(src_label_path, dst_label_path)
                    print(f"Moved label: {label_name}")
                    
                    # Read the existing line
                    with open(dst_label_path, 'r') as f:
                        original_line = f.readline().strip()

                    # Prepend the fine-grained label
                    new_line = f"{new_label} {original_line}"

                    # Write it back
                    with open(dst_label_path, 'w') as f:
                        f.write(new_line + '\n')

                else:
                    print(f"Label not found in unlabeled: {label_name}")
# Out:
# Moved image: Empty_split_Fly082324_8-08232024150416_ds_1Hz_19858.jpg
# Moved label: Empty_split_Fly082324_8-08232024150416_ds_1Hz_19858.txt
# Moved image: empty_split_2-09082024134341_ds_10Hz_20677.jpg
# Moved label: empty_split_2-09082024134341_ds_10Hz_20677.txt
# Moved image: empty_split_14-09172024143211_ds_10Hz_6008.jpg
# Moved label: empty_split_14-09172024143211_ds_10Hz_6008.txt
# Moved image: empty_split_2-09082024134341_ds_10Hz_8661.jpg
# Moved label: empty_split_2-09082024134341_ds_10Hz_8661.txt
# Moved image: Empty_split_Fly082324_10-08232024165942_ds_1Hz_34719.jpg
# Moved label: Empty_split_Fly082324_10-08232024165942_ds_1Hz_34719.txt
# Moved image: R30_1-09102024114816_ds_1Hz_6143.jpg
# Moved label: R30_1-09102024114816_ds_1Hz_6143.txt
# Moved image: 53771_7-09112024152638_ds_1Hz_708.jpg
# Moved label: 53771_7-09112024152638_ds_1Hz_708.txt
# Moved image: empty_split_9-09162024161248_ds_10Hz_10197.jpg
# Moved label: empty_split_9-09162024161248_ds_10Hz_10197.txt
# Moved image: R30_2-09102024121314_ds_1Hz_7782.jpg
# Moved label: R30_2-09102024121314_ds_1Hz_7782.txt
# Moved image: empty_split_8-09162024154241_ds_10Hz_2372.jpg
# Moved label: empty_split_8-09162024154241_ds_10Hz_2372.txt
# Moved image: 53771_12-09122024154820_ds_1Hz_300.jpg
# Moved label: 53771_12-09122024154820_ds_1Hz_300.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_13284.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_13284.txt
# Moved image: R23E10_9_17_2-09202024121149_ds_10Hz_25228.jpg
# Moved label: R23E10_9_17_2-09202024121149_ds_10Hz_25228.txt
# Moved image: Empty_Split_Fly082124_5-08212024173159_ds_1Hz_26970.jpg
# Moved label: Empty_Split_Fly082124_5-08212024173159_ds_1Hz_26970.txt
# Moved image: empty_split_11-09172024131855_ds_10Hz_10043.jpg
# Moved label: empty_split_11-09172024131855_ds_10Hz_10043.txt
# Moved image: empty_split_13-09172024140845_ds_10Hz_18197.jpg
# Moved label: empty_split_13-09172024140845_ds_10Hz_18197.txt
# Moved image: 53771_6-09112024142637_ds_1Hz_10033.jpg
# Moved label: 53771_6-09112024142637_ds_1Hz_10033.txt
# Moved image: R23E10_9_17_3-09202024123413_ds_10Hz_29706.jpg
# Moved label: R23E10_9_17_3-09202024123413_ds_10Hz_29706.txt
# Moved image: 53771_1-09112024104748_ds_1Hz_20835.jpg
# Moved label: 53771_1-09112024104748_ds_1Hz_20835.txt
# Moved image: empty_split_13-09172024140845_ds_10Hz_10515.jpg
# Moved label: empty_split_13-09172024140845_ds_10Hz_10515.txt
# Moved image: empty_split_3-09082024163011_ds_10Hz_32019.jpg
# Moved label: empty_split_3-09082024163011_ds_10Hz_32019.txt
# Moved image: 53771_11-09122024152536_ds_1Hz_25072.jpg
# Moved label: 53771_11-09122024152536_ds_1Hz_25072.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_28071.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_28071.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_27389.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_27389.txt
# Moved image: empty_split_7-09162024145849_ds_10Hz_5724.jpg
# Moved label: empty_split_7-09162024145849_ds_10Hz_5724.txt
# Moved image: R30_4-09102024130227_ds_1Hz_3182.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_3182.txt
# Moved image: R23E10_9_17_3-09202024123413_ds_10Hz_23161.jpg
# Moved label: R23E10_9_17_3-09202024123413_ds_10Hz_23161.txt
# Moved image: R23E10_9_17_2-09202024121149_ds_10Hz_3825.jpg
# Moved label: R23E10_9_17_2-09202024121149_ds_10Hz_3825.txt
# Moved image: empty_split_15-09172024145422_ds_10Hz_28750.jpg
# Moved label: empty_split_15-09172024145422_ds_10Hz_28750.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_4376.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_4376.txt
# Moved image: R23E10_9_18_6-09212024134646_ds_10Hz_32742.jpg
# Moved label: R23E10_9_18_6-09212024134646_ds_10Hz_32742.txt
# Moved image: empty_split_6-09162024143142_ds_10Hz_9898.jpg
# Moved label: empty_split_6-09162024143142_ds_10Hz_9898.txt
# Moved image: R23E10_9_17_3-09202024123413_ds_10Hz_33489.jpg
# Moved label: R23E10_9_17_3-09202024123413_ds_10Hz_33489.txt
# Moved image: Empty_split_Fly082624_11-08262024163145_ds_1Hz_8872.jpg
# Moved label: Empty_split_Fly082624_11-08262024163145_ds_1Hz_8872.txt
# Moved image: empty_split_4-09162024131209_ds_10Hz_17785.jpg
# Moved label: empty_split_4-09162024131209_ds_10Hz_17785.txt
# Moved image: SS54320_Fly090124_10-09012024163145_ds_1Hz_1380.jpg
# Moved label: SS54320_Fly090124_10-09012024163145_ds_1Hz_1380.txt
# Moved image: SS54320_9_12_11-09192024120215_ds_10Hz_3367.jpg
# Moved label: SS54320_9_12_11-09192024120215_ds_10Hz_3367.txt
# Moved image: SS55832_2-09242024162750_ds_1Hz_5576.jpg
# Moved label: SS55832_2-09242024162750_ds_1Hz_5576.txt
# Moved image: empty_split_4-09162024131209_ds_10Hz_7926.jpg
# Moved label: empty_split_4-09162024131209_ds_10Hz_7926.txt
# Moved image: SS55832_Fly081724_11-08172024160843_ds_1Hz_16026.jpg
# Moved label: SS55832_Fly081724_11-08172024160843_ds_1Hz_16026.txt
# Moved image: R30G03-R58H05_9_11_1-09162024121530_ds_1Hz_21789.jpg
# Moved label: R30G03-R58H05_9_11_1-09162024121530_ds_1Hz_21789.txt
# Moved image: 53771_12-09122024154820_ds_1Hz_8111.jpg
# Moved label: 53771_12-09122024154820_ds_1Hz_8111.txt
# Moved image: empty_split_3-09082024163011_ds_10Hz_5127.jpg
# Moved label: empty_split_3-09082024163011_ds_10Hz_5127.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_19115.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_19115.txt
# Moved image: SS54320_9_12_11-09192024120215_ds_10Hz_19794.jpg
# Moved label: SS54320_9_12_11-09192024120215_ds_10Hz_19794.txt
# Moved image: empty_split_8-09162024154241_ds_10Hz_19570.jpg
# Moved label: empty_split_8-09162024154241_ds_10Hz_19570.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_13582.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_13582.txt
# Moved image: SS55832_9_17_12-09202024114625_ds_10Hz_16922.jpg
# Moved label: SS55832_9_17_12-09202024114625_ds_10Hz_16922.txt
# Moved image: SS54320_9_18_2-09242024123033_ds_10Hz_5977.jpg
# Moved label: SS54320_9_18_2-09242024123033_ds_10Hz_5977.txt
# Moved image: SS54320_9_12_10-09182024174014_ds_10Hz_11765.jpg
# Moved label: SS54320_9_12_10-09182024174014_ds_10Hz_11765.txt
# Moved image: SS53771_9_10_15-09142024163508_ds_1Hz_15662.jpg
# Moved label: SS53771_9_10_15-09142024163508_ds_1Hz_15662.txt
# Moved image: SS53771_9_10_16-09142024165617_ds_1Hz_23549.jpg
# Moved label: SS53771_9_10_16-09142024165617_ds_1Hz_23549.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_15013.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_15013.txt
# Moved image: 53771_10-09122024145749_ds_1Hz_14378.jpg
# Moved label: 53771_10-09122024145749_ds_1Hz_14378.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_11511.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_11511.txt
# Moved image: R30_R58_9_10_1-09132024122306_ds_1Hz_28891.jpg
# Moved label: R30_R58_9_10_1-09132024122306_ds_1Hz_28891.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_10593.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_10593.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_14259.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_14259.txt
# Moved image: empty_split_2-09082024134341_ds_10Hz_2214.jpg
# Moved label: empty_split_2-09082024134341_ds_10Hz_2214.txt
# Moved image: empty_split_15-09172024145422_ds_10Hz_13074.jpg
# Moved label: empty_split_15-09172024145422_ds_10Hz_13074.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_11990.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_11990.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_6855.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_6855.txt
# Moved image: 53771_12-09122024154820_ds_1Hz_12480.jpg
# Moved label: 53771_12-09122024154820_ds_1Hz_12480.txt
# Moved image: empty_split_10-09172024125302_ds_10Hz_31485.jpg
# Moved label: empty_split_10-09172024125302_ds_10Hz_31485.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_12288.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_12288.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_13657.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_13657.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_12594.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_12594.txt
# Moved image: SS55832_Fly081724_7-08172024134041_ds_1Hz_24144.jpg
# Moved label: SS55832_Fly081724_7-08172024134041_ds_1Hz_24144.txt
# Moved image: empty_split_3-09082024163011_ds_10Hz_5780.jpg
# Moved label: empty_split_3-09082024163011_ds_10Hz_5780.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_20870.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_20870.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_304.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_304.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_9152.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_9152.txt
# Moved image: 53771_7-09112024152638_ds_1Hz_525.jpg
# Moved label: 53771_7-09112024152638_ds_1Hz_525.txt
# Moved image: SS54320_9_12_10-09182024174014_ds_10Hz_7705.jpg
# Moved label: SS54320_9_12_10-09182024174014_ds_10Hz_7705.txt
# Moved image: R23E10_9_18_6-09212024134646_ds_10Hz_35621.jpg
# Moved label: R23E10_9_18_6-09212024134646_ds_10Hz_35621.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_14709.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_14709.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_8376.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_8376.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_16956.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_16956.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_4004.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_4004.txt
# Moved image: empty_split_12-09172024134134_ds_10Hz_24392.jpg
# Moved label: empty_split_12-09172024134134_ds_10Hz_24392.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_31425.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_31425.txt
# Moved image: empty_split_3-09082024163011_ds_10Hz_8712.jpg
# Moved label: empty_split_3-09082024163011_ds_10Hz_8712.txt
# Moved image: SS55832_9_17_12-09202024114625_ds_10Hz_5326.jpg
# Moved label: SS55832_9_17_12-09202024114625_ds_10Hz_5326.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_15326.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_15326.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_28843.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_28843.txt
# Moved image: empty_split_8-09162024154241_ds_10Hz_17591.jpg
# Moved label: empty_split_8-09162024154241_ds_10Hz_17591.txt
# Moved image: 53771_6-09112024142637_ds_1Hz_26172.jpg
# Moved label: 53771_6-09112024142637_ds_1Hz_26172.txt
# Moved image: R23E10_1-09032024170117_ds_10Hz_21454.jpg
# Moved label: R23E10_1-09032024170117_ds_10Hz_21454.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_89.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_89.txt
# Moved image: R23E10_9_18_6-09212024134646_ds_10Hz_31039.jpg
# Moved label: R23E10_9_18_6-09212024134646_ds_10Hz_31039.txt
# Moved image: SS55832_9_17_12-09202024114625_ds_10Hz_12855.jpg
# Moved label: SS55832_9_17_12-09202024114625_ds_10Hz_12855.txt
# Moved image: empty_split_12-09172024134134_ds_10Hz_3609.jpg
# Moved label: empty_split_12-09172024134134_ds_10Hz_3609.txt
# Moved image: 53771_5-09112024135106_ds_1Hz_3784.jpg
# Moved label: 53771_5-09112024135106_ds_1Hz_3784.txt
# Moved image: SS55832_9_17_12-09202024114625_ds_10Hz_22129.jpg
# Moved label: SS55832_9_17_12-09202024114625_ds_10Hz_22129.txt
# Moved image: 53771_3-09112024125236_ds_1Hz_19802.jpg
# Moved label: 53771_3-09112024125236_ds_1Hz_19802.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_2013.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_2013.txt
# Moved image: SS55832_Fly081724_11-08172024160843_ds_1Hz_23091.jpg
# Moved label: SS55832_Fly081724_11-08172024160843_ds_1Hz_23091.txt
# Moved image: SS55832_Fly081624_4-08162024153158_ds_1Hz_20011.jpg
# Moved label: SS55832_Fly081624_4-08162024153158_ds_1Hz_20011.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_31156.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_31156.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_17270.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_17270.txt
# Moved image: SS55832_9_15_10-09202024104950_ds_10Hz_8091.jpg
# Moved label: SS55832_9_15_10-09202024104950_ds_10Hz_8091.txt
# Moved image: SS55832_Fly081724_9-08172024145104_ds_1Hz_16543.jpg
# Moved label: SS55832_Fly081724_9-08172024145104_ds_1Hz_16543.txt
# Moved image: Empty_split_Fly082324_10-08232024165942_ds_1Hz_20969.jpg
# Moved label: Empty_split_Fly082324_10-08232024165942_ds_1Hz_20969.txt
# Moved image: R23E10_9_18_4-09212024125336_ds_10Hz_29275.jpg
# Moved label: R23E10_9_18_4-09212024125336_ds_10Hz_29275.txt
# Moved image: SS55832_Fly081724_11-08172024160843_ds_1Hz_28461.jpg
# Moved label: SS55832_Fly081724_11-08172024160843_ds_1Hz_28461.txt
# Moved image: R23E10_9_18_10-09212024152135_ds_10Hz_33910.jpg
# Moved label: R23E10_9_18_10-09212024152135_ds_10Hz_33910.txt
# Moved image: SS55832_9_15_7-09192024160143_ds_10Hz_6130.jpg
# Moved label: SS55832_9_15_7-09192024160143_ds_10Hz_6130.txt
# Moved image: SS55832_9_15_10-09202024104950_ds_10Hz_11972.jpg
# Moved label: SS55832_9_15_10-09202024104950_ds_10Hz_11972.txt
# Moved image: SS55832_Fly081724_7-08172024134041_ds_1Hz_30452.jpg
# Moved label: SS55832_Fly081724_7-08172024134041_ds_1Hz_30452.txt
# Moved image: empty_split_3-09082024163011_ds_10Hz_3819.jpg
# Moved label: empty_split_3-09082024163011_ds_10Hz_3819.txt
# Moved image: empty_split_2-09082024134341_ds_10Hz_8981.jpg
# Moved label: empty_split_2-09082024134341_ds_10Hz_8981.txt
# Moved image: Empty_split_Fly082624_12-08262024170552_ds_1Hz_1009.jpg
# Moved label: Empty_split_Fly082624_12-08262024170552_ds_1Hz_1009.txt
# Moved image: SS55832_9_15_8-09192024164035_ds_10Hz_5803.jpg
# Moved label: SS55832_9_15_8-09192024164035_ds_10Hz_5803.txt
# Moved image: SS55832_9_17_11-09202024112303_ds_10Hz_5129.jpg
# Moved label: SS55832_9_17_11-09202024112303_ds_10Hz_5129.txt
# Moved image: empty_split_14-09172024143211_ds_10Hz_9947.jpg
# Moved label: empty_split_14-09172024143211_ds_10Hz_9947.txt
# Moved image: empty_split_2-09082024134341_ds_10Hz_29593.jpg
# Moved label: empty_split_2-09082024134341_ds_10Hz_29593.txt
# Moved image: R30_4-09102024130227_ds_1Hz_10696.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_10696.txt
# Moved image: R30_4-09102024130227_ds_1Hz_11273.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_11273.txt
# Moved image: R23E10_9_18_8-09212024143518_ds_10Hz_13894.jpg
# Moved label: R23E10_9_18_8-09212024143518_ds_10Hz_13894.txt
# Moved image: R30_R58_9_10_1-09132024122306_ds_1Hz_15621.jpg
# Moved label: R30_R58_9_10_1-09132024122306_ds_1Hz_15621.txt
# Moved image: R30_4-09102024130227_ds_1Hz_11605.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_11605.txt
# Moved image: R30_R58_2-09122024173058_ds_1Hz_17019.jpg
# Moved label: R30_R58_2-09122024173058_ds_1Hz_17019.txt
# Moved image: SS54320_9_18_4-09242024132319_ds_10Hz_10524.jpg
# Moved label: SS54320_9_18_4-09242024132319_ds_10Hz_10524.txt
# Moved image: R30_3-09102024123749_ds_1Hz_11399.jpg
# Moved label: R30_3-09102024123749_ds_1Hz_11399.txt
# Moved image: SS54320_Fly090124_10-09012024163145_ds_1Hz_18464.jpg
# Moved label: SS54320_Fly090124_10-09012024163145_ds_1Hz_18464.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_20187.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_20187.txt
# Moved image: R23E10_9_18_5-09212024132106_ds_10Hz_18427.jpg
# Moved label: R23E10_9_18_5-09212024132106_ds_10Hz_18427.txt
# Moved image: SS54320_Fly083124_5-08312024160138_ds_1Hz_19512.jpg
# Moved label: SS54320_Fly083124_5-08312024160138_ds_1Hz_19512.txt
# Moved image: 53771_10-09122024145749_ds_1Hz_25475.jpg
# Moved label: 53771_10-09122024145749_ds_1Hz_25475.txt
# Moved image: R30_1-09102024114816_ds_1Hz_13274.jpg
# Moved label: R30_1-09102024114816_ds_1Hz_13274.txt
# Moved image: SS54320_Fly083124_6-08312024163802_ds_1Hz_29351.jpg
# Moved label: SS54320_Fly083124_6-08312024163802_ds_1Hz_29351.txt
# Moved image: SS54320_2-09042024132500_ds_10Hz_33587.jpg
# Moved label: SS54320_2-09042024132500_ds_10Hz_33587.txt
# Moved image: SS55832_9_15_5-09192024151152_ds_10Hz_29095.jpg
# Moved label: SS55832_9_15_5-09192024151152_ds_10Hz_29095.txt
# Moved image: SS54320_Fly083124_4-08312024151809_ds_1Hz_23666.jpg
# Moved label: SS54320_Fly083124_4-08312024151809_ds_1Hz_23666.txt
# Moved image: R30_4-09102024130227_ds_1Hz_16242.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_16242.txt
# Moved image: R23E10_9_18_7-09212024140858_ds_10Hz_35372.jpg
# Moved label: R23E10_9_18_7-09212024140858_ds_10Hz_35372.txt
# Moved image: R23E10_9_18_9-09212024145833_ds_10Hz_22773.jpg
# Moved label: R23E10_9_18_9-09212024145833_ds_10Hz_22773.txt
# Moved image: R30_4-09102024130227_ds_1Hz_14723.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_14723.txt
# Moved image: R30_4-09102024130227_ds_1Hz_15531.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_15531.txt
# Moved image: SS54320_9_12_6-09182024144511_ds_10Hz_22905.jpg
# Moved label: SS54320_9_12_6-09182024144511_ds_10Hz_22905.txt
# Moved image: R30_4-09102024130227_ds_1Hz_15810.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_15810.txt
# Moved image: R30_3-09102024123749_ds_1Hz_13941.jpg
# Moved label: R30_3-09102024123749_ds_1Hz_13941.txt
# Moved image: empty_split_1-09082024124850_ds_10Hz_25461.jpg
# Moved label: empty_split_1-09082024124850_ds_10Hz_25461.txt
# Moved image: SS54320_Fly083124_4-08312024151809_ds_1Hz_23810.jpg
# Moved label: SS54320_Fly083124_4-08312024151809_ds_1Hz_23810.txt
# Moved image: R30_R58_2-09122024173058_ds_1Hz_15121.jpg
# Moved label: R30_R58_2-09122024173058_ds_1Hz_15121.txt
# Moved image: R30_4-09102024130227_ds_1Hz_16094.jpg
# Moved label: R30_4-09102024130227_ds_1Hz_16094.txt
# Moved image: R30_1-09102024114816_ds_1Hz_12170.jpg
# Moved label: R30_1-09102024114816_ds_1Hz_12170.txt
# Moved image: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_25279.jpg
# Moved label: Empty_Split_Fly082124_3-08212024161659_ds_1Hz_25279.txt
